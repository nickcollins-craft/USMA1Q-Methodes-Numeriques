# %% [markdown]
# # Python pour l'Ingénierie des Matériaux
# ## Séance 1 — Feuille d'exercices
#
# **Conservatoire National des Arts et Métiers**
# *03 Mars 2026*
#
# ---
#
# Cette feuille d'exercices accompagne la séance 1. Elle est divisée en cinq parties :
#
# | Partie | Thème |
# |--------|-------|
# | 1 | Variables et types de données |
# | 2 | Opérateurs et expressions |
# | 3 | Structures de contrôle (`if`/`elif`/`else`) |
# | 4 | Boucles (`for`, `while`) |
# | 5 | Mini-projet guidé |
#
# > **Conseil :** Lisez l'énoncé entier avant d'écrire la moindre ligne de code.
# > Ajoutez des commentaires (`#`) pour expliquer votre raisonnement.

# %% [markdown]
# ---
# ## Partie 1 — Variables et types de données

# %% [markdown]
# ### Exercice 1.1 — Création et affichage de variables
#
# Créez les quatre variables suivantes, chacune d'un type différent, puis affichez leur valeur **et** leur type avec `print()` et `type()` :
#
# | Variable | Type attendu |
# |----------|----------------|
# | `nb_pieces` | `int` |
# | `temperature` | `float` |
# | `nom_alliage` | `str` |
# | `test_reussi` | `bool` |
#
# *Exemple de sortie attendue pour la première variable :*
# ```
# nb_pieces = 42   type : <class 'int'>
# ```

# %%
# Exercice 1.1 — à compléter

# Entier
nb_pieces = ...

# Flottant
temperature = ...

# Chaîne de caractères
nom_alliage = ...

# Booléen
test_reussi = ...

# Affichage
print("nb_pieces  =", nb_pieces, "  type :", type(nb_pieces))
# Compléter pour les trois autres variables...

# %% [markdown]
# ### Exercice 1.2 — Précision `int` vs `float`
#
# Exécutez les expressions suivantes **dans la cellule de code**, observez les résultats et répondez aux questions dans la cellule Markdown ci-dessous :
#
# ```python
# a = 7 / 2
# b = 7 // 2
# c = 7 % 2
# d = 1 / 3
# e = int(3.9)
# f = float(5)
# ```
#
# **Questions :**
# 1. Quelle est la différence entre `a` et `b` ?
# 2. Que vaut `c` et pourquoi ?
# 3. `e` vaut-il `4` ou `3` ? Pourquoi ?
# 4. Quel serait le type de `f` ?

# %%
# Exercice 1.2 — exécuter et observer
a = 7 / 2
b = 7 // 2
c = 7 % 2
d = 1 / 3
e = int(3.9)
f = float(5)

print("a =", a, "  type:", type(a))
print("b =", b, "  type:", type(b))
print("c =", c, "  type:", type(c))
print("d =", d, "  type:", type(d))
print("e =", e, "  type:", type(e))
print("f =", f, "  type:", type(f))

# %% [markdown]
# **Vos réponses ici :**
#
# 1. ...
# 2. ...
# 3. ...
# 4. ...

# %% [markdown]
# ### Exercice 1.3 — Manipulation de listes
#
# Soit la liste suivante :
# ```python
# notes = [12, 15, 9, 18, 11, 14, 7, 16]
# ```
#
# Utilisant seulement l'indexation et `len`, écrivez le code pour :
#
# 1. Afficher le **premier** et le **dernier** élément.
# 2. Afficher le **nombre** d'éléments.
# 3. Afficher les **trois premiers** éléments (utilisez le *slicing* `liste[a:b]`).
# 4. Ajouter la note `13` à la fin de la liste, puis afficher la nouvelle longueur.
# 5. Afficher la liste dans l'**ordre inverse** (utilisez `liste[::-1]`).

# %%
# Exercice 1.3 — à compléter
notes = [12, 15, 9, 18, 11, 14, 7, 16]

# 1. Premier et dernier élément
print("Premier :", ...)
print("Dernier :", ...)

# 2. Nombre d'éléments
print("Longueur :", ...)

# 3. Trois premiers éléments
print("Trois premiers :", ...)

# 4. Ajouter 13 au fin, afficher la nouvelle longueur
notes...
print("Nouvelle longueur :", ...)

# 5. Ordre inverse
print("Inversée :", ...)

# %% [markdown]
# ---
# ## Partie 2 — Opérateurs et expressions

# %% [markdown]
# ### Exercice 2.1 — Opérateurs de base
#
# Sans utiliser Python, **calculez mentalement** le résultat de chaque expression, puis vérifiez dans la cellule de code.
#
# | Expression | Votre estimation | Résultat Python |
# |------------|-----------------|----------------|
# | `3 + 4 * 2` | ? | |
# | `(3 + 4) * 2` | ? | |
# | `2 ** 3 ** 2` | ? | |
# | `17 // 5` | ? | |
# | `17 % 5` | ? | |
# | `-7 % 3` | ? | |
#
# > *Note :* L'ordre de priorité en Python suit les règles algébriques standard, mais l'opérateur `**` est **associatif à droite** : `2**3**2` s'évalue comme `2**(3**2)`.

# %%
# Exercice 2.1 — vérification
print(3 + 4 * 2)
print((3 + 4) * 2)
print(2 ** 3 ** 2)
print(17 // 5)
print(17 % 5)
print(-7 % 3)

# %% [markdown]
# ### Exercice 2.2 — Grandeurs d'ingénierie
#
# Écrivez un script Python qui effectue les quatre calculs suivants. Utilisez des **variables nommées** et **commentez chaque étape**.
#
# 1. **Conversion** : convertir une contrainte de 450 MPa en GPa.
#    *(Rappel : 1 GPa = 1 000 MPa)*
#
# 2. **Moyenne de dureté** : calculer la moyenne des cinq mesures Brinell suivantes :
#    `245, 251, 238, 260, 249`
#
# 3. **Taux d'allongement** (%) selon la formule :
#    $$
#    A = \frac{L_f - L_0}{L_0} \times 100
#    $$
#    avec $L_0 = 50{,}0$ mm et $L_f = 63{,}5$ mm.
#
# 4. **Volume d'un cylindre** :
#    $$
#    V = \pi r^2 h
#    $$
#    avec $r = 12{,}5$ mm et $h = 80$ mm.
#    *(Utilisez `3.14159` pour π, ou ajouter la ligne `import math` au debut du block et utilisez `math.pi` où c'est requi)*

# %%
# Exercice 2.2 — à compléter

# ── 1. Conversion MPa → GPa ───────────────────────────────────────────────────
sigma_mpa = 450.0
sigma_gpa = ...  # à compléter
print("1. Contrainte :", sigma_gpa, "GPa")

# ── 2. Moyenne de dureté ──────────────────────────────────────────────────────
# Valeurs : 245, 251, 238, 260, 249 — additionner sans sum()
durete_moy = ...
print("2. Dureté moyenne :", round(durete_moy, 1), "HB")

# ── 3. Taux d'allongement ─────────────────────────────────────────────────────
L0 = 50.0   # mm — longueur initiale
Lf = 63.5   # mm — longueur finale
A = ...     # formule à compléter
print("3. Allongement :", round(A, 1), "%")

# ── 4. Volume du cylindre ─────────────────────────────────────────────────────
pi = 3.14159
r = 12.5   # mm — rayon
h = 80.0   # mm — hauteur
V = ...    # formule à compléter
print("4. Volume :", round(V, 1), "mm3")

# %% [markdown]
# ### Exercice 2.3 — Opérateurs `//` et `%` en pratique
#
# Ces deux opérateurs sont utiles dans de nombreuses situations concrètes.
#
# 1. **Parité** : écrivez une expression booléenne qui vaut `True` si un entier `n` est pair, `False` sinon. Testez avec `n = 7` et `n = 12`.
#
# 2. **Partitionnement** : on dispose de `53` éprouvettes à répartir en groupes de `8`.
#    - Combien de groupes **complets** obtient-on ?
#    - Combien d'éprouvettes restent-elles **sans groupe** ?
#
# 3. **Conversion d'unité de temps** : une expérience dure `3 875` secondes.
#    Affichez la durée au format `H h MM min SS s`.

# %%
# Exercice 2.3 — à compléter

# ── 1. Parité ─────────────────────────────────────────────────────────────────
n = 7
est_pair = ...  # expression booléenne
print("n =", n, "est pair :", est_pair)

n = 12
est_pair = ...
print("n =", n, "est pair :", est_pair)

# ── 2. Partitionnement d'éprouvettes ──────────────────────────────────────────
nb_eprouvettes = 53
taille_groupe = 8

nb_groupes_complets = ...
nb_restantes        = ...

print("Groupes complets :", nb_groupes_complets)
print("Éprouvettes restantes :", nb_restantes)

# ── 3. Conversion de secondes ─────────────────────────────────────────────────
duree_s = 3875

heures   = ...
minutes  = ...
secondes = ...

print("Durée :", heures, "h", minutes, "min", secondes, "s")

# %% [markdown]
# ---
# ## Partie 3 — Structures de contrôle (`if` / `elif` / `else`)

# %% [markdown]
# ### Exercice 3.1 — Comparaisons et logique booléenne (échauffement)
#
# **Sans exécuter Python**, prédisez la valeur (`True` ou `False`) de chaque expression, puis vérifiez.
#
# | Expression | Votre prédiction | Résultat |
# |------------|-----------------|----------|
# | `5 > 3 and 2 < 4` | ? | |
# | `5 > 3 and 2 > 4` | ? | |
# | `5 > 3 or 2 > 4` | ? | |
# | `not (5 == 5)` | ? | |
# | `3 != 3` | ? | |
# | `10 >= 10` | ? | |
# | `True and False or True` | ? | |
# | `True and (False or True)` | ? | |

# %%
# Exercice 3.1 — vérification
print(5 > 3 and 2 < 4)
print(5 > 3 and 2 > 4)
print(5 > 3 or 2 > 4)
print(not (5 == 5))
print(3 != 3)
print(10 >= 10)
print(True and False or True)
print(True and (False or True))

# %% [markdown]
# ### Exercice 3.2 — Années bissextiles
#
# Une année est **bissextile** si elle respecte la règle suivante :
#
# > Divisible par **4**,
# > **sauf** si divisible par **100**,
# > **sauf** si divisible par **400** (auquel cas elle est bissextile malgré tout).
#
# Écrivez un bloc `if / elif / else` qui affiche `"bissextile"` ou `"non bissextile"` pour une variable `annee`.
#
# Testez avec : 2000, 1900, 2024, 2100, 2023.
#
# | Année | Résultat attendu |
# |-------|------------------|
# | 2000 | bissextile |
# | 1900 | non bissextile |
# | 2024 | bissextile |
# | 2100 | non bissextile |
# | 2023 | non bissextile |

# %%
# Exercice 3.2 — à compléter

liste_des_années = ...
index = ...

# Tester chaque année manuellement
if liste_des_années[index] ...

# %% [markdown]
# ### Exercice 3.3 — Classification par module de Young
#
# Le module de Young $E$ (en GPa) permet de classer grossièrement les matériaux :
#
# | Classe | Intervalle de *E* |
# |--------|-------------------|
# | Polymère souple | $E < 5$ GPa |
# | Métal léger (Al, Ti…) | $5 \leq E < 80$ GPa |
# | Acier / Fonte | $80 \leq E < 250$ GPa |
# | Céramique dense | $E \geq 250$ GPa |
#
# Écrivez un bloc `if / elif / else` qui affiche la classe d'un matériau donné par sa valeur de `E`.
# Testez avec : `E = 3.0`, `E = 70.0`, `E = 210.0`, `E = 380.0`.

# %%
# Exercice 3.3 — à compléter
liste_des_modules = ...
index = ...
if ...

# %% [markdown]
# ### Exercice 3.4 — Contrôle qualité multi-critères
#
# Un spécimen doit satisfaire **trois critères** simultanément pour être déclaré conforme :
#
# | Critère | Seuil |
# |---------|-------|
# | Résistance à la traction $R_m$ | $\geq 500$ MPa |
# | Allongement à rupture $A$ | $\geq 12$ % |
# | Dureté Brinell HB | entre 200 et 280 (inclus) |
#
# Testez les deux spécimens suivants :
#
# | Spécimen | $R_m$ (MPa) | $A$ (%) | HB |
# |----------|-------------|---------|----|
# | A | 487 | 15 | 235 |
# | B | 530 | 9 | 265 |
#
# Pour chaque spécimen, affichez `"Conforme"` ou `"Non conforme"`, **et** indiquez quel(s) critère(s) ne sont pas satisfaits le cas échéant.

# %%
# Exercice 3.4 — à compléter

specimens = [
    {"nom": "A", "Rm": 487, "A": 15, "HB": 235},
    {"nom": "B", "Rm": 530, "A": 9,  "HB": 265},
]
specimen_index = ...
if specimens[specimen_index]...

# %% [markdown]
# ---
# ## Partie 4 — Boucles (`for` et `while`)

# %% [markdown]
# ### Exercice 4.1 — Patron accumulateur
#
# Voici une liste de températures de traitement thermique (en °C) :
# ```python
# temperatures = [820, 835, 810, 850, 825, 840, 815, 830, 845, 820]
# ```
#
# En utilisant une boucle `for` et le patron accumulateur, calculez :
#
# 1. La **somme** de toutes les températures.
# 2. La **température minimale**.
# 3. La **température maximale**.
# 4. Le **nombre de températures** strictement supérieures à 830 °C.
#
# *Rappel du patron accumulateur :*
# ```python
# total = 0
# for v in liste:
#     total += v
# ```

# %%
# Exercice 4.1 — à compléter
temperatures = [820, 835, 810, 850, 825, 840, 815, 830, 845, 820]

# ── 1. Somme ──────────────────────────────────────────────────────────────────
total = 0
for t in temperatures:
    ...  # accumuler
print("Somme :", total, "°C")

# ── 2. Minimum ────────────────────────────────────────────────────────────────
mini = temperatures[0]   # initialisation
for t in temperatures:
    if ...:
        mini = t
print("Minimum :", mini, "°C")

# ── 3. Maximum ────────────────────────────────────────────────────────────────
maxi = temperatures[0]
for t in temperatures:
    ...
print("Maximum :", maxi, "°C")

# ── 4. Comptage > 830 °C ──────────────────────────────────────────────────────
compteur = 0
for t in temperatures:
    ...
print("Valeurs > 830 °C :", compteur)

# %% [markdown]
# ### Exercice 4.2 — Statistiques avec une boucle `while`
#
# Reprenez la liste `temperatures` de l'exercice précédent. Cette fois, **utilisez une boucle `while`** (avec un indice `i`) pour calculer la somme, puis la moyenne.
#
# Cet exercice illustre que `for` et `while` peuvent accomplir la même tâche — l'un ou l'autre est simplement plus naturel selon la situation.

# %%
# Exercice 4.2 — à compléter
temperatures = [820, 835, 810, 850, 825, 840, 815, 830, 845, 820]

total = 0
i = 0

while i < len(temperatures):
    total += ...         # accumuler la valeur à l'indice i
    i += 1               # ne pas oublier !

moyenne = total / len(temperatures)
print("Moyenne :", round(moyenne, 1), "°C")

# %% [markdown]
# ### Exercice 4.3 — Moyenne et écart-type par boucle
#
# Soit les dix mesures de dureté Brinell suivantes :
# ```python
# durete = [245, 251, 238, 260, 249, 253, 247, 255, 241, 258]
# ```
#
# À l'aide de boucles `for`, calculez **sans utiliser** `sum()` ni les fonctions de `math` ou `statistics` :
#
# 1. La **somme** et la **moyenne** $\bar{x}$.
# 2. La **variance** (population) :
#    $$s^2 = \frac{1}{n}\sum_{i=1}^{n}(x_i - \bar{x})^2$$
# 3. L'**écart-type** $s = \sqrt{s^2}$ *(utilisez `** 0.5` ou `** (1/2)`)*.
#
# Vérifiez vos résultats :
# - Moyenne ≈ 249.7 HB
# - Écart-type ≈ 6.97 HB
#
# > *Indication :* deux boucles séparées sont nécessaires — la première calcule la moyenne, la seconde calcule la somme des carrés des écarts.

# %%
# Exercice 4.3 — à compléter
durete = [245, 251, 238, 260, 249, 253, 247, 255, 241, 258]
n = len(durete)

# ── 1. Somme et moyenne ───────────────────────────────────────────────────────
total = 0
for v in durete:
    total += ...
moyenne = ...
print("Moyenne      :", round(moyenne, 2), "HB")

# ── 2. Variance ───────────────────────────────────────────────────────────────
somme_carres = 0
for v in durete:
    somme_carres += ...   # (v - moyenne)²
variance = ...
print("Variance     :", round(variance, 4), "HB2")

# ── 3. Écart-type ─────────────────────────────────────────────────────────────
ecart_type = ...
print("Écart-type   :", round(ecart_type, 2), "HB")

# %% [markdown]
# ### Exercice 4.4 — Suite de Fibonacci et `while`
#
# La **suite de Fibonacci** est définie par la relation de récurrence :
# $$F_0 = 0,\quad F_1 = 1,\quad F_n = F_{n-1} + F_{n-2} \text{ pour } n \geq 2$$
#
# 1. Utilisez une boucle `while` pour calculer et afficher tous les termes de Fibonacci **inférieurs à 500**.
# 2. Comptez combien il y en a.
# 3. *(Bonus)* Affichez pour chaque terme $F_n$ le rapport $\frac{F_n}{F_{n-1}}$ (sauf pour $F_0$).
#    Que remarquez-vous quand $n$ devient grand ?

# %%
# Exercice 4.4 — à compléter

# ── 1 & 2. Termes de Fibonacci < 500 ─────────────────────────────────────────
a = 0   # F_{n-2}
b = 1   # F_{n-1}
compteur = 0

while a < 500:
    print(a)
    compteur += 1
    a, b = ...  # mise à jour simultanée

print("Nombre de termes < 500 :", compteur)

# ── 3. Rapport F_n / F_{n-1} ─────────────────────────────────────────────────
print("Rapports F_n / F_(n-1) :")
a, b = 0, 1
while b < 500:
    if a > 0:   # éviter la division par zéro
        rapport = ...
        print("  F =", b, "  rapport =", round(rapport, 6))
    a, b = b, a + b

# %% [markdown]
# ---
# ## Partie 5 — Mini-projet guidé : Contrôle de deux lots de pièces forgées
#
# ### Scénario
#
# Vous travaillez dans un bureau de contrôle qualité. Un four de forge a produit **deux lots** de 10 pièces chacun (lot A et lot B).
# Vous disposez des mesures de dureté Brinell (HB) relevées sur chaque pièce des deux lots.
#
# Le cahier des charges impose :
# - Dureté **moyenne** $\geq$ 240 HB
# - **Écart-type** $\leq$ 15 HB *(dispersion maîtrisée)*
#
# **Votre mission :**
#
# 1. Stocker les deux lots dans une liste de listes.
# 2. À l'aide de **boucles imbriquées** (boucle extérieure sur les lots, boucle intérieure sur les valeurs), calculer la **moyenne** et l'**écart-type** de chaque lot.
# 3. Afficher si chaque lot est **conforme** ou **non conforme** aux deux critères.
# 4. Identifier les pièces **individuellement hors tolérance** (HB < 230 ou HB > 270) dans chaque lot.
# 5. Rédiger une **analyse d'ingénierie** (cellule Markdown) — les deux lots sont-ils acceptables ?

# %%
# Mini-projet — données
# Deux lots de 10 mesures de dureté Brinell (HB)
lot_a = ...
lot_b = ...

# On regroupe les deux lots dans une liste de listes
# Chaque élément de `lots` est lui-même une liste de mesures
lots = ...

# Seuils du cahier des charges
...

# %%
# ── Étape 2 : Statistiques — boucles imbriquées ───────────────────────────────
#
# Boucle EXTÉRIEURE : on parcourt chaque lot
# Boucles INTÉRIEURES : on parcourt les valeurs du lot pour calculer les stats
#
# On stocke les résultats pour les réutiliser aux étapes 3 et 4.
moyennes = []
ecarts = ... 

for i in range(len(lots)):
    ...

# %%
# ── Étape 3 : Conformité de chaque lot ───────────────────────────────────────

for i in range(len(lots)):
    ...

# %%
# ── Étape 4 : Pièces hors tolérance individuelle ─────────────────────────────
for i in range(len(lots)):
    ...

# %% [markdown]
# ### Étape 5 — Analyse d'ingénierie
#
# *Rédigez ici votre analyse en vous appuyant sur les résultats ci-dessus.*
#
# ---
#
# **Rappel des résultats numériques :**
#
# | | Lot A | Lot B |
# |-|-------|-------|
# | Moyenne (HB) | ___ | ___ |
# | Écart-type (HB) | ___ | ___ |
# | Pièces hors tolérance | ___ | ___ |
# | Conforme ? | ___ | ___ |
#
# **Évaluation du procédé :**
# *(Les deux lots sont-ils acceptables ? L'un est-il meilleur que l'autre ? Y a-t-il des dérives entre les lots ? Des actions correctives sont-elles nécessaires ? Justifiez.)*
#
# *Votre analyse ici…*
